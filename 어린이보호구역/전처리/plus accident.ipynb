# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 사고, 보호구역 현황 데이터 불러오기

# %%
accident = pd.read_excel('C:/Users/wnrrh/desktop/data/전처리/accident.xlsx',header=0)
df = pd.read_excel('C:/Users/wnrrh/desktop/data/전처리/boho_final.xlsx',header=0)

# %%
columns = ["사고번호","사고일시","시군구","사망자수","중상자수","경상자수",
           "부상신고자수","가해운전자 차종","피해운전자 차종","피해운전자 연령",
           "시간대","행정동",'시설명']
accident.columns = columns

# %%
columns = ['시설명','시간대','주소','시설종류','구역지정수','CCTV 수',
           '도로표지판 수','과속방지턱 수','위도','경도','CCTV설치여부',
    '보호구역도로폭','tmp','속도','도로명','행정동','자치구','총생활인구수']
df.columns = columns

# %%
df['시간대'] = df['시간대'].apply(lambda _: str(_))
accident['시간대'] = accident['시간대'].apply(lambda _: str(_))

# %%
df
# Out:
#              시설명 시간대                                 주소     시설종류  구역지정수  \
# 0      GKL행복어린이집   0          서울특별시 강남구 삼성로122길 7 (삼성동)     어린이집      1
# 1      GKL행복어린이집   1          서울특별시 강남구 삼성로122길 7 (삼성동)     어린이집      1
# 2      GKL행복어린이집   2          서울특별시 강남구 삼성로122길 7 (삼성동)     어린이집      1
# 3      GKL행복어린이집   3          서울특별시 강남구 삼성로122길 7 (삼성동)     어린이집      1
# 4      GKL행복어린이집   4          서울특별시 강남구 삼성로122길 7 (삼성동)     어린이집      1
# ...          ...  ..                                ...      ...    ...
# 36235     희망찬유치원  19  서울특별시 성북구 동소문로34길 24 (돈암동, 삼성아파트)  유치원(일반)      1
# 36236     희망찬유치원  20  서울특별시 성북구 동소문로34길 24 (돈암동, 삼성아파트)  유치원(일반)      1
# 36237     희망찬유치원  21  서울특별시 성북구 동소문로34길 24 (돈암동, 삼성아파트)  유치원(일반)      1
# 36238     희망찬유치원  22  서울특별시 성북구 동소문로34길 24 (돈암동, 삼성아파트)  유치원(일반)      1
# 36239     희망찬유치원  23  서울특별시 성북구 동소문로34길 24 (돈암동, 삼성아파트)  유치원(일반)      1
#
#        CCTV 수  도로표지판 수  과속방지턱 수         위도          경도 CCTV설치여부  보호구역도로폭  \
# ...

# %%
data = pd.merge(df,accident,on=['시간대','시설명'],how='inner')
data
# Out:
#             시설명 시간대                                 주소     시설종류  구역지정수  \
# 0    LG전자구로어린이집  19            서울특별시 구로구 가마산로 95 (구로동)     어린이집      1
# 1        가락초등학교  12         서울특별시 송파구 송파대로37길 45 (가락동)     초등학교      2
# 2        가양초등학교   1            서울특별시 강서구 허준로 186 (가양동)     초등학교      5
# 3        가주초등학교   9          서울특별시 송파구 오금로40길 37 (가락동)     초등학교      2
# 4        가주초등학교  15          서울특별시 송파구 오금로40길 37 (가락동)     초등학교      2
# ..          ...  ..                                ...      ...    ...
# 752      후암초등학교  12               서울특별시 용산구 두텁바위로 140      초등학교      2
# 753      후암초등학교  18               서울특별시 용산구 두텁바위로 140      초등학교      2
# 754      흥인초등학교  19                 서울특별시 중구 청구로6길 11      초등학교      1
# 755      흥인초등학교  22                 서울특별시 중구 청구로6길 11      초등학교      1
# 756      희망찬유치원  18  서울특별시 성북구 동소문로34길 24 (돈암동, 삼성아파트)  유치원(일반)      1
#
#      CCTV 수    도로표지판 수  과속방지턱 수         위도          경도  ...  \
# ...

# %%
data.to_excel('C:/Users/wnrrh/desktop/data/sample.xlsx')
