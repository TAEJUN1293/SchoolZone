# %%
import pandas as pd
import numpy as np

# %%
accident = pd.read_csv('C:/Users/wnrrh/desktop/data/전처리/사고.csv',header=0)
df = pd.read_excel('C:/Users/wnrrh/desktop/data/전처리/보호구역 현황.xlsx',header=0)
accident2 = pd.read_excel('C:/Users/wnrrh/desktop/data/전처리/accident2.xlsx',header = 0)

# %% [markdown]
# 사고 데이터 처리

# %%
columns = ["사고번호","사고일시","요일","시군구","사고내용","사망자수","중상자수",
          "경상자수","부상신고자수","사고유형","법규위반","노면상태","기상상태",
          "도로형태","가해운전자 차종","가해운전자 성별","가해운전자 연령","가해운전자 상해정도",
          "피해운전자 차종","피해운전자 성별","피해운전자 연령","피해운전자 상해정도"]
accident.columns = columns

# %%
accident = accident.drop(['요일','사고유형','법규위반','노면상태','기상상태',
              '도로형태','가해운전자 성별','가해운전자 연령','가해운전자 상해정도',
              '피해운전자 성별','피해운전자 상해정도','사고내용'],axis=1, inplace=False)

# %%
accident['사고일시'] = accident['사고일시'].astype('str')
accident['사고일시'].dtypes
data_list = accident['사고일시'].str.split(' ')
data_list.head()
accident['시간대'] = data_list.str.get(3)
accident

# %%
accident['시군구'] = accident['시군구'].astype('str')
accident['시군구'].dtypes
data_list = accident['시군구'].str.split(' ')
data_list.head()
accident['행정동'] = data_list.str.get(2)
accident

# %% [markdown]
# 가해정도, 피해정도가 큰 순서대로 숫자 대입

# %%
accident['가해운전자 차종'].unique()
# Out:
# array(['승용', '이륜', '화물', '원동기', '승합', '기타불명', '자전거', '건설기계', '특수',
#        '개인형이동수단(PM)'], dtype=object)

# %%
accident['가해운전자 차종'].replace('자전거','1',inplace = True)
accident['가해운전자 차종'].replace('기타불명','10',inplace = True)
accident['가해운전자 차종'].replace('이륜','2',inplace = True)
accident['가해운전자 차종'].replace('원동기','4',inplace = True)
accident['가해운전자 차종'].replace('승용','5',inplace = True)
accident['가해운전자 차종'].replace('승합','6',inplace = True)
accident['가해운전자 차종'].replace('화물','7',inplace = True)
accident['가해운전자 차종'].replace('건설기계','8',inplace = True)
accident['가해운전자 차종'].replace('특수','9',inplace = True)
accident['가해운전자 차종'].replace('개인형이동수단(PM)','3',inplace = True)

# %%
accident['피해운전자 차종'].unique()
# Out:
# array(['보행자', '자전거', '승용', '원동기', '화물', '승합', '이륜', nan, '특수', '미분류',
#        '기타불명'], dtype=object)

# %%
accident['피해운전자 차종'].replace('특수','1',inplace = True)
accident['피해운전자 차종'].replace('화물','2',inplace = True)
accident['피해운전자 차종'].replace('승합','3',inplace = True)
accident['피해운전자 차종'].replace('승용','4',inplace = True)
accident['피해운전자 차종'].replace('원동기','5',inplace = True)
accident['피해운전자 차종'].replace('이륜','6',inplace = True)
accident['피해운전자 차종'].replace('자전거','7',inplace = True)
accident['피해운전자 차종'].replace('미분류','8',inplace = True)
accident['피해운전자 차종'].replace('보행자','9',inplace = True)
accident['피해운전자 차종'].replace('기타불명','10',inplace = True)
accident
# Out:
#                   사고번호               사고일시            시군구  사망자수  중상자수  경상자수  \
# 0     2015010600100080    2015년 1월 6일 05시  서울특별시 용산구 후암동     1     0     0
# 1     2015010700100290    2015년 1월 7일 15시   서울특별시 종로구 계동     0     1     0
# 2     2015011400100116   2015년 1월 14일 09시  서울특별시 관악구 신림동     0     0     1
# 3     2015011400100205   2015년 1월 14일 13시  서울특별시 중랑구 면목동     0     0     1
# 4     2015012600100101   2015년 1월 26일 08시  서울특별시 양천구 신정동     0     0     1
# ...                ...                ...            ...   ...   ...   ...
# 1391  2020122000100348  2020년 12월 20일 23시  서울특별시 관악구 봉천동     0     0     1
# 1392  2020122100100593  2020년 12월 21일 21시  서울특별시 성북구 석관동     0     0     1
# 1393  2020122800100232  2020년 12월 28일 13시  서울특별시 동작구 대방동     0     0     1
# 1394  2020122800100237  2020년 12월 28일 13시  서울특별시 은평구 갈현동     0     0     1
# 1395  2020123100100527  2020년 12월 31일 21시  서울특별시 동작구 사당동     0     1     0
#
#       부상신고자수 가해운전자 차종 피해운전자 차종 피해운전자 연령  시간대  행정동
# ...

# %% [markdown]
# 나이 앞자리 따라서 대입

# %%
# Out:
#   File "<ipython-input-22-b6b52ba71873>", line 1
#     accident[(accident['가해운전자 차종'] == '승용')] =
#                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 보호구역 데이터에 병합

# %%
columns = ['시설명','시간대구분','주소','시설종류','구역지정수','CCTV 수',
           '도로표지판 수','과속방지턱 수','위도','경도','CCTV설치여부',
           '보호구역도로폭','속도','도로명','행정동','자치구','총생활인구수','1','2']
df.columns = columns
df
# Out:
#                시설명  시간대구분                                주소     시설종류  구역지정수  \
# 0            도원유치원      0            서울특별시 용산구 새창로12길 11-8       유치원      2
# 1           새현대유치원      0  서울특별시 마포구 새창로 52 (도화동, 도화동현대아파트)  유치원(일반)      3
# 2          진선미어린이집      0        서울특별시 마포구 마포대로4나길 28 (마포동)     어린이집      2
# 3      마포초등학교병설유치원      0           서울특별시 마포구 도화2길 64 (도화동)  유치원(병설)      0
# 4         서울마포초등학교      0           서울특별시 마포구 도화2길 64 (도화동)     초등학교      2
# ...            ...    ...                               ...      ...    ...
# 36067       숭미초등학교     21           서울특별시 도봉구 노해로 179 (쌍문동)     초등학교      4
# 36068     쌍문삼성어린이집     22           서울특별시 도봉구 노해로 238 (쌍문동)     어린이집      1
# 36069       숭미초등학교     22           서울특별시 도봉구 노해로 179 (쌍문동)     초등학교      4
# 36070     쌍문삼성어린이집     23           서울특별시 도봉구 노해로 238 (쌍문동)     어린이집      1
# 36071       숭미초등학교     23           서울특별시 도봉구 노해로 179 (쌍문동)     초등학교      4
#
# ...

# %%
df.drop(['1','2'],axis=1, inplace=True)

# %%
df['시간대구분'] = df['시간대구분'].astype('int')
df['시간대구분'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# 사고 + 보호구역 현황

# %%
columns = ["사고번호","사고일시","시군구","사망자수","중상자수","경상자수",
           "부상신고자수","가해운전자 차종","피해운전자 차종","피해운전자 연령",
           "피해운전자 상해정도","행정동",'시설명']
accident2.columns = columns

# %%
accident2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1396 entries, 0 to 1395
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        1396 non-null   int64
#  1   사고일시        1396 non-null   object
#  2   시군구         1396 non-null   object
#  3   사망자수        1396 non-null   int64
#  4   중상자수        1396 non-null   int64
#  5   경상자수        1396 non-null   int64
#  6   부상신고자수      1396 non-null   int64
#  7   가해운전자 차종    1396 non-null   object
#  8   피해운전자 차종    1371 non-null   object
#  9   피해운전자 연령    1371 non-null   object
#  10  피해운전자 상해정도  1396 non-null   object
#  11  행정동         1396 non-null   object
#  12  시설명         1396 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 141.9+ KB

# %%
dataframe = pd.merge(accident2, df, on=['시설명'])
dataframe
# Out:
#                    사고번호              사고일시            시군구  사망자수  중상자수  경상자수  \
# 0      2015062400100406  2015년 6월 24일 17시  서울특별시 강남구 수서동     0     0     1
# 1      2015062400100406  2015년 6월 24일 17시  서울특별시 강남구 수서동     0     0     1
# 2      2015062400100406  2015년 6월 24일 17시  서울특별시 강남구 수서동     0     0     1
# 3      2015062400100406  2015년 6월 24일 17시  서울특별시 강남구 수서동     0     0     1
# 4      2015062400100406  2015년 6월 24일 17시  서울특별시 강남구 수서동     0     0     1
# ...                 ...               ...            ...   ...   ...   ...
# 18115  2019020100100289   2019년 2월 1일 13시  서울특별시 중랑구 중화동     0     1     0
# 18116  2019020100100289   2019년 2월 1일 13시  서울특별시 중랑구 중화동     0     1     0
# 18117  2019020100100289   2019년 2월 1일 13시  서울특별시 중랑구 중화동     0     1     0
# 18118  2019020100100289   2019년 2월 1일 13시  서울특별시 중랑구 중화동     0     1     0
# 18119  2019020100100289   2019년 2월 1일 13시  서울특별시 중랑구 중화동     0     1     0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36072 entries, 0 to 36071
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시설명       36072 non-null  object
#  1   시간대구분     36072 non-null  int64
#  2   주소        36072 non-null  object
#  3   시설종류      36072 non-null  object
#  4   구역지정수     36072 non-null  int64
#  5   CCTV 수    36072 non-null  int64
#  6   도로표지판 수   36072 non-null  float64
#  7   과속방지턱 수   36072 non-null  int64
#  8   위도        36024 non-null  float64
#  9   경도        36000 non-null  float64
#  10  CCTV설치여부  36072 non-null  object
#  11  보호구역도로폭   36072 non-null  float64
#  12  속도        36072 non-null  float64
#  13  도로명       36072 non-null  object
#  14  행정동       36072 non-null  object
#  15  자치구       36072 non-null  object
#  16  총생활인구수    36072 non-null  float64
# dtypes: float64(6), int64(4), object(7)
# memory usage: 4.7+ MB

# %%
accident2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1396 entries, 0 to 1395
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        1396 non-null   int64
#  1   사고일시        1396 non-null   object
#  2   시군구         1396 non-null   object
#  3   사망자수        1396 non-null   int64
#  4   중상자수        1396 non-null   int64
#  5   경상자수        1396 non-null   int64
#  6   부상신고자수      1396 non-null   int64
#  7   가해운전자 차종    1396 non-null   object
#  8   피해운전자 차종    1371 non-null   object
#  9   피해운전자 연령    1371 non-null   object
#  10  피해운전자 상해정도  1396 non-null   object
#  11  행정동         1396 non-null   object
#  12  시설명         0 non-null      float64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 141.9+ KB
